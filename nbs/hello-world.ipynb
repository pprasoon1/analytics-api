# %%
print("Hello world")
# Out:
# Hello world

# %%
# %pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/prasoon/Developer/analytics-api/venv/lib/python3.9/site-packages (from requests) (3.11)
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.4-cp39-cp39-macosx_10_9_universal2.whl (209 kB)
#      |████████████████████████████████| 209 kB 677 kB/s eta 0:00:01
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.6.2-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 4.3 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
#      |████████████████████████████████| 159 kB 2.0 MB/s eta 0:00:01
# Installing collected packages: urllib3, charset-normalizer, certifi, requests
# Successfully installed certifi-2025.11.12 charset-normalizer-3.4.4 requests-2.32.5 urllib3-2.6.2
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/prasoon/Developer/analytics-api/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
#import httpx
# Out:
# /Users/prasoon/Developer/analytics-api/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
path = "/healthz"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/healthz'

# %%
response = requests.get(endpoint)
print(response.ok)
# Out:
# True
